# %% [markdown]
# Implementing linear regression. Theory:
# When doing grpahs like in physics, we use the data to create  a regression line. Thanks to that we can predict the value using the slope (m).
# I wish to work with y = mx + b0.
# y (values) = b0 + b1(m) * x  + errors [in general].
#
# theyre all matrixes. so y[] = X[]*B[b0, b1(m)] +E[]
#
# nultyplying matrixes, y[] = XB[]+ E[]
#
# Transposing is when the cols and the rows swhich (90 degree rotation to the matrix) as it seen as X^T.
#
# X^T * X = X^T X
# Inverse : 1/ (itself)
# X^T X * (X^T X)^-1 = I (Identity matrix) where I is eqvialet to 1 when multiplying.
#
# I want to calucate the B matrix's values.
#
# so: y = XB + e
# let's remove the focus from the errors.
#
# y = XB   / * X^T
# y * X^T =  X* X^T * B   / * (X^T*X)-1  (the Inverse)
#
# y * X^T * (X^T*X)^-1 = I * B = B
#
# B = y * X^T * (X^T*X)^-1

# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3072569317.py in <cell line: 0>()
# ----> 1 print(os.getcwd())
#
# NameError: name 'os' is not defined

# %%
teams = pd.read_csv('project\\teams.csv')
teams.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1167318482.py in <cell line: 0>()
# ----> 1 teams = pd.read_csv('project\\teams.csv')
#       2 teams.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
